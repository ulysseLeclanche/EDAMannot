# %% [markdown]
# # Implementing EDAM inferences
#
# ## Working on a toy example

# %%
# !pip install rdflib

from rdflib import Graph
# Out:
# Requirement already satisfied: rdflib in /Users/gaignard-a/miniconda3/envs/abromics-kg/lib/python3.10/site-packages (7.0.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /Users/gaignard-a/miniconda3/envs/abromics-kg/lib/python3.10/site-packages (from rdflib) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /Users/gaignard-a/miniconda3/envs/abromics-kg/lib/python3.10/site-packages (from rdflib) (3.1.2)
# Requirement already satisfied: six in /Users/gaignard-a/miniconda3/envs/abromics-kg/lib/python3.10/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)

# %%
my_edam_light = """
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix owl: <http://www.w3.org/2002/07/owl#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix edam: <http://edamontology.org/> .

edam:C rdf:type owl:Class .
edam:C_prime rdf:type owl:Class .
edam:Topic_1 rdf:type owl:Class .
edam:Operation_1 rdf:type owl:Class .
edam:Data_1 rdf:type owl:Class .

edam:C rdfs:subClassOf edam:C_prime .

## C_prime --> implies --> Topic 1 .
edam:C_prime  rdfs:subClassOf [
        rdf:type owl:Restriction ;
        owl:onProperty edam:has_topic ;
        owl:someValuesFrom edam:Topic_1 ;
    ] .
### --> ASSERTION 1: C should have topic Topic1 (by transitivity of subClassOf)

## Topic1 --> implies --> Operation 1
edam:Topic_1 rdfs:subClassOf [
        rdf:type owl:Restriction ;
        owl:onProperty edam:has_operation ;
        owl:someValuesFrom edam:Operation_1 ;
    ] .
### --> ASSERTION 2: C should have operation Operation_1

## Operation 1 --> implies --> Data 1 as OUTPUT
edam:Operation_1 rdfs:subClassOf [
        rdf:type owl:Restriction ;
        owl:onProperty edam:has_output ;
        owl:someValuesFrom edam:Data_1 ;
    ] .
### --> ASSERTION 3: C should have as output Data_1


edam:Topic_1 rdfs:subClassOf edam:Topic_2 .
edam:Topic_2 rdfs:subClassOf [
        rdf:type owl:Restriction ;
        owl:onProperty edam:has_operation ;
        owl:someValuesFrom edam:Operation_2 ;
    ] .
### --> ASSERTION 4: C should have operation Operation_2

## Operation 2 --> implies --> Data 2 as INPUT
edam:Operation_2 rdfs:subClassOf [
        rdf:type owl:Restriction ;
        owl:onProperty edam:has_input ;
        owl:someValuesFrom edam:Data_2 ;
    ] .
### --> ASSERTION 5: C should have as input Data_2

"""

# %%
kg = Graph()
kg.parse(data=my_edam_light, format="turtle")
print(len(kg))
print(kg.serialize(format="turtle"))
# Out:
# 27
# @prefix edam: <http://edamontology.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# edam:C a owl:Class ;
#     rdfs:subClassOf edam:C_prime .
#
# edam:C_prime a owl:Class ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onProperty edam:has_topic ;
#             owl:someValuesFrom edam:Topic_1 ] .
#
# edam:Data_1 a owl:Class .
#
# edam:Operation_1 a owl:Class ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onProperty edam:has_output ;
#             owl:someValuesFrom edam:Data_1 ] .
#
# edam:Operation_2 rdfs:subClassOf [ a owl:Restriction ;
#             owl:onProperty edam:has_input ;
#             owl:someValuesFrom edam:Data_2 ] .
#
# edam:Topic_1 a owl:Class ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onProperty edam:has_operation ;
#             owl:someValuesFrom edam:Operation_1 ],
#         edam:Topic_2 .
#
# edam:Topic_2 rdfs:subClassOf [ a owl:Restriction ;
#             owl:onProperty edam:has_operation ;
#             owl:someValuesFrom edam:Operation_2 ] .

# %% [markdown]
# Sous la forme de règles :
# ```
# RULE1: C hasTopic T AND T hasOperation O --> C hasOperation O
# RULE2: C hasOperation O AND O hasInput D --> C hasInput D
# RULE3: C hasOperation O AND O hasOutput D --> C hasOutput D
# RULE4: C hasInput D AND D hasTopic T --> C hasTopic T
# RULE5: C hasOutput D AND D hasTopic T --> C hasTopic T
# RULE6: C hasInput D AND D hasOperation O --> C hasOperation O
# RULE7: C hasOutput D AND D hasOperation O --> C hasOperation O
# ```

# %%
import time

rule_subClassOf = """
PREFIX edam: <http://edamontology.org/>
CONSTRUCT {
  # ?concept edam:has_topic ?topic ;
           edam:has_operation ?operation ;
           edam:has_input ?in_data ;
           edam:has_output ?out_data .

} WHERE {
    # ?concept rdfs:subClassOf* ?super_concept .
    OPTIONAL { ?super_concept edam:has_topic ?topic } .
    OPTIONAL { ?super_concept edam:has_operation ?operation } .
    OPTIONAL { ?super_concept edam:has_input ?in_data } .
    OPTIONAL { ?super_concept edam:has_output ?out_data } .
}
"""

rule_0 = """
PREFIX edam: <http://edamontology.org/>
CONSTRUCT {
  # ?concept ?rel ?class .
  # ?class rdf:type owl:Class .
} WHERE {
    # ?concept rdfs:subClassOf [
        rdf:type owl:Restriction ;
        owl:onProperty ?rel ;
        owl:someValuesFrom ?class ;
    ] .
}
"""

rule_1 = """
PREFIX edam: <http://edamontology.org/>
CONSTRUCT {
  # ?concept edam:has_operation ?operation .
} WHERE {
  # ?concept rdf:type owl:Class .
  # ?concept edam:has_topic ?topic .
  # ?topic edam:has_operation ?operation .
}
"""

rule_1_bis = """
PREFIX edam: <http://edamontology.org/>
CONSTRUCT {
  # ?concept edam:has_topic ?topic .
} WHERE {
  # ?concept rdf:type owl:Class .
  # ?concept edam:has_operation ?operation .
  # ?operation edam:has_topic ?topic .
}
"""

rule_2 = """
PREFIX edam: <http://edamontology.org/>
CONSTRUCT {
  # ?concept edam:has_input ?data .
} WHERE {
  # ?concept rdf:type owl:Class .
  # ?concept edam:has_operation ?op .
  # ?op edam:has_input ?data .
}
"""

rule_3 = """
PREFIX edam: <http://edamontology.org/>
CONSTRUCT {
  # ?concept edam:has_output ?data .
} WHERE {
  # ?concept rdf:type owl:Class .
  # ?concept edam:has_operation ?op .
  # ?op edam:has_output ?data .
}
"""

rule_4 = """
PREFIX edam: <http://edamontology.org/>
CONSTRUCT {
  # ?concept edam:has_topic ?topic .
} WHERE {
  # ?concept rdf:type owl:Class .
  # ?concept edam:has_input ?data .
  # ?data edam:has_topic ?topic .
}
"""

rule_5 = """
PREFIX edam: <http://edamontology.org/>
CONSTRUCT {
  # ?concept edam:has_topic ?topic .
} WHERE {
  # ?concept rdf:type owl:Class .
  # ?concept edam:has_output ?data .
  # ?data edam:has_topic ?topic .
}
"""

rule_6 = """
PREFIX edam: <http://edamontology.org/>
CONSTRUCT {
  # ?concept edam:has_operation ?operation .
} WHERE {
  # ?concept rdf:type owl:Class .
  # ?concept edam:has_input ?data .
  # ?data edam:has_operation ?operation .
}
"""

rule_7 = """
PREFIX edam: <http://edamontology.org/>
CONSTRUCT {
  # ?concept edam:has_operation ?operation .
} WHERE {
  # ?concept rdf:type owl:Class .
  # ?concept edam:has_output ?data .
  # ?data edam:has_operation ?operation .
}
"""

rules = [rule_0, rule_1, rule_1_bis, rule_2, rule_3, rule_4, rule_5, rule_6, rule_7]


def apply_all_rules(kg):
    """
    Apply the construct rules defined in the rules parameter, as well as the
    transitivity of subClassOf
    """

    inferred_kg = Graph()
    inferred_kg += kg

    for i, rule in enumerate(rules):
        res_kg = inferred_kg.query(rule).graph
        print(
            f"{len(inferred_kg + res_kg) - len(inferred_kg)} triples generated from rule {i}"
        )
        inferred_kg = inferred_kg + res_kg

    res_kg = inferred_kg.query(rule_subClassOf).graph
    print(
        f"{len(inferred_kg + res_kg) - len(inferred_kg)} triples generated from rule subClassOf"
    )
    inferred_kg = inferred_kg + res_kg

    return inferred_kg


def transitive_closure(kg):
    """
    Apply the collection of inference rules iteratively until no new triples are generated.
    Apply rules for 10 iteration max
    Return the resulting knowledge graph.
    """
    card_new_triples = 1
    i = 1
    while card_new_triples > 0:
        timer = time.time()

        kg_with_inferrences = apply_all_rules(kg)

        new_triples = kg_with_inferrences - kg
        card_new_triples = len(new_triples)
        print(f"Inferred {card_new_triples} new triples")

        kg += kg_with_inferrences
        duration = time.time() - timer
        print(f"Iteration {i} Duration : {round(duration, 2)}s")
        i += 1
        if i > 10:
            break
    return kg

# %%
kg_2 = transitive_closure(kg)
print(len(kg_2))
print(kg_2.serialize(format="turtle"))
# Out:
# 0 triples generated from rule 0
# 0 triples generated from rule 1
# 0 triples generated from rule 2
# 0 triples generated from rule 3
# 0 triples generated from rule 4
# 0 triples generated from rule 5
# 0 triples generated from rule 6
# 0 triples generated from rule 7
# 0 triples generated from rule 8
# 0 triples generated from rule subClassOf
# Inferred 0 new triples
# Iteration 1 Duration : 0.05s
# 46
# @prefix edam: <http://edamontology.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# edam:C a owl:Class ;
#     edam:has_input edam:Data_2 ;
#     edam:has_operation edam:Operation_1,
#         edam:Operation_2 ;
#     edam:has_output edam:Data_1 ;
#     edam:has_topic edam:Topic_1 ;
#     rdfs:subClassOf edam:C_prime .
#
# edam:C_prime a owl:Class ;
#     edam:has_input edam:Data_2 ;
#     edam:has_operation edam:Operation_1,
#         edam:Operation_2 ;
#     edam:has_output edam:Data_1 ;
#     edam:has_topic edam:Topic_1 ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onProperty edam:has_topic ;
#             owl:someValuesFrom edam:Topic_1 ] .
#
# edam:Topic_2 edam:has_operation edam:Operation_2 ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onProperty edam:has_operation ;
#             owl:someValuesFrom edam:Operation_2 ] .
#
# edam:Topic_1 a owl:Class ;
#     edam:has_input edam:Data_2 ;
#     edam:has_operation edam:Operation_1,
#         edam:Operation_2 ;
#     edam:has_output edam:Data_1 ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onProperty edam:has_operation ;
#             owl:someValuesFrom edam:Operation_1 ],
#         edam:Topic_2 .
#
# edam:Operation_1 a owl:Class ;
#     edam:has_output edam:Data_1 ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onProperty edam:has_output ;
#             owl:someValuesFrom edam:Data_1 ] .
#
# edam:Data_1 a owl:Class .
#
# edam:Data_2 a owl:Class .
#
# edam:Operation_2 a owl:Class ;
#     edam:has_input edam:Data_2 ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onProperty edam:has_input ;
#             owl:someValuesFrom edam:Data_2 ] .

# %% [markdown]
# ## Applying the same rule set to the full bio.tools and EDAM knowledge graph

# %%
full_kg = Graph()
full_kg.parse("https://edamontology.org/EDAM.owl", format="xml")
print(f"Successfully loaded EDAM: {len(full_kg)} triples")
# Out:
# Successfully loaded EDAM: 38792 triples

# %%
full_kg.parse(
    "https://github.com/research-software-ecosystem/content/raw/refs/heads/master/datasets/bioschemas-dump.ttl",
    format="turtle",
)
print(f"Successfully loaded bio.tools: {len(full_kg)} triples")
# Out:
# Successfully loaded bio.tools: 672116 triples

# %%
full_inferred_kg = transitive_closure(full_kg)
print(len(full_inferred_kg))
# Out:
# 604 triples generated from rule 0
# 0 triples generated from rule 1
# 0 triples generated from rule 2
# 0 triples generated from rule 3
# 0 triples generated from rule 4
# 25 triples generated from rule 5
# 17 triples generated from rule 6
# 0 triples generated from rule 7
# 0 triples generated from rule 8
# 1549 triples generated from rule subClassOf
# Inferred 2195 new triples
# Iteration 1 Duration : 140.52s
# 0 triples generated from rule 0
# 0 triples generated from rule 1
# 0 triples generated from rule 2
# 0 triples generated from rule 3
# 0 triples generated from rule 4
# 9 triples generated from rule 5
# 12 triples generated from rule 6
# 0 triples generated from rule 7
# 0 triples generated from rule 8
# 0 triples generated from rule subClassOf
# Inferred 21 new triples
# Iteration 2 Duration : 148.26s
# 0 triples generated from rule 0
# 0 triples generated from rule 1
# 0 triples generated from rule 2
# 0 triples generated from rule 3
# 0 triples generated from rule 4
# 0 triples generated from rule 5
# 0 triples generated from rule 6
# 0 triples generated from rule 7
# 0 triples generated from rule 8
# 0 triples generated from rule subClassOf
# Inferred 0 new triples
# Iteration 3 Duration : 144.44s
# 674332

# %%
full_inferred_kg.serialize(destination="out_inf.ttl", format="turtle")
# Out:
# <Graph identifier=N8b99de6896714ad98a9b4c851a927238 (<class 'rdflib.graph.Graph'>)>

# %%
full_inferred_kg = Graph()
full_inferred_kg.parse("out_inf.ttl", format="turtle")
print(f"Successfully loaded inferred KG: {len(full_inferred_kg)} triples")
# Out:
# Successfully loaded inferred KG: 674332 triples

# %%
desc_q = """
DESCRIBE <https://bio.tools/multiqc> <https://bio.tools/qiime2> <https://bio.tools/frogs> 
"""
res = full_inferred_kg.query(desc_q).graph
print(res.serialize(format="turtle"))
# Out:
# @prefix biotools: <https://bio.tools/ontology/> .
# @prefix bsc: <http://bioschemas.org/> .
# @prefix bsct: <http://bioschemas.org/types/> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix edam: <http://edamontology.org/> .
# @prefix sc: <http://schema.org/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://bio.tools/frogs> a sc:SoftwareApplication ;
#     dcterms:conformsTo "https://bioschemas.org/profiles/ComputationalTool/0.6-DRAFT" ;
#     sc:additionalType "Command-line tool" ;
#     sc:applicationSubCategory edam:topic_0637,
#         edam:topic_3168,
#         edam:topic_3174,
#         edam:topic_3299,
#         edam:topic_3697 ;
#     sc:citation <https://doi.org/10.1093/bib/bbab318>,
#         <https://doi.org/10.1093/bioinformatics/btx791>,
#         "pubmed:29228191",
#         "pubmed:34410336" ;
#     sc:description "The user-friendly and Galaxy-supported pipeline FROGS analyses large sets of DNA amplicons sequences accurately and rapidly, essential for microbe community studies." ;
#     sc:featureList edam:operation_3460 ;
#     sc:license "GPL-3.0" ;
#     sc:name "FROGS" ;
#     sc:operatingSystem "Linux" ;
#     sc:softwareHelp <https://github.com/geraldinepascal/FROGS> ;
#     sc:softwareVersion "4.0.0" ;
#     sc:url "http://frogs.toulouse.inra.fr/" ;
#     biotools:primaryContact "Géraldine Pascal" .
#
# <https://bio.tools/multiqc> a sc:SoftwareApplication ;
#     bsc:output [ a bsct:FormalParameter ;
#             sc:additionalType edam:data_0867 ;
#             sc:encodingFormat edam:format_2331 ;
#             sc:name "Sequence alignment report" ],
#         [ a bsct:FormalParameter ;
#             sc:additionalType edam:data_3914 ;
#             sc:encodingFormat edam:format_2331,
#                 edam:format_3464,
#                 edam:format_3475,
#                 edam:format_3750,
#                 edam:format_3752 ;
#             sc:name "Quality control report" ] ;
#     dcterms:conformsTo "https://bioschemas.org/profiles/ComputationalTool/0.6-DRAFT" ;
#     sc:additionalType "Command-line tool",
#         "Library" ;
#     sc:applicationSubCategory edam:topic_0080,
#         edam:topic_0091,
#         edam:topic_0622,
#         edam:topic_3168 ;
#     sc:citation <https://doi.org/10.1093/bioinformatics/btw354>,
#         "pmcid:PMC5039924",
#         "pubmed:27312411" ;
#     sc:description "MultiQC aggregates results from multiple bioinformatics analyses across many samples into a single report. It searches a given directory for analysis logs and compiles a HTML report. It's a general use tool, perfect for summarising the output from numerous bioinformatics tools." ;
#     sc:featureList edam:operation_2428,
#         edam:operation_3218 ;
#     sc:isAccessibleForFree true ;
#     sc:license "GPL-3.0" ;
#     sc:name "MultiQC" ;
#     sc:operatingSystem "Linux",
#         "Mac",
#         "Windows" ;
#     sc:softwareHelp <http://multiqc.info/docs/> ;
#     sc:url "http://multiqc.info/" ;
#     biotools:primaryContact <http://orcid.org/0000-0003-4101-2502> .
#
# <https://bio.tools/qiime2> a sc:SoftwareApplication ;
#     dcterms:conformsTo "https://bioschemas.org/profiles/ComputationalTool/0.6-DRAFT" ;
#     sc:additionalType "Command-line tool",
#         "Library",
#         "Suite" ;
#     sc:applicationSubCategory edam:topic_3174,
#         edam:topic_3697,
#         edam:topic_3941 ;
#     sc:citation <https://doi.org/10.1038/s41587-019-0209-9>,
#         "pmcid:PMC7015180",
#         "pubmed:31341288" ;
#     sc:description "QIIME 2 is an AI-ready microbiome multi-omics data science platform that is trusted, free, open source, extensible, and community developed and supported bioinformatics." ;
#     sc:featureList edam:operation_0337,
#         edam:operation_3460,
#         edam:operation_3933 ;
#     sc:isAccessibleForFree true ;
#     sc:license "BSD-3-Clause" ;
#     sc:name "QIIME 2" ;
#     sc:operatingSystem "Linux",
#         "Mac",
#         "Windows" ;
#     sc:softwareHelp <https://amplicon-docs.qiime2.org>,
#         <https://develop.qiime2.org>,
#         <https://library.qiime2.org/books>,
#         <https://moshpit.qiime2.org>,
#         <https://use.qiime2.org> ;
#     sc:softwareVersion "2.0" ;
#     sc:url "https://qiime2.org" ;
#     biotools:primaryContact "Greg Caporaso" .

# %%
q = """
PREFIX edam: <http://edamontology.org/> 
PREFIX bsc: <http://bioschemas.org/> 
PREFIX sc: <http://schema.org/> 

CONSTRUCT {
  # ?X sc:applicationSubCategory ?topic, ?inf_ot, ?inf_odt, ?inf_idt ;
                            sc:featureList ?operation, ?inf_to, ?inf_odo, ?inf_ido ;
                            bsc:output ?out_data, ?inf_tod, ?inf_ood ;
                            bsc:input ?in_data, ?inf_tid, ?inf_oid  .    
} WHERE {
    VALUES ?X { <https://bio.tools/multiqc> <https://bio.tools/qiime2> <https://bio.tools/frogs> }
    # ?X a sc:SoftwareApplication .
    OPTIONAL {?X bsc:output/sc:additionalType ?out_data } . 
    OPTIONAL {?X bsc:output/sc:additionalType/edam:has_topic ?inf_odt } . 
    OPTIONAL {?X bsc:output/sc:additionalType/edam:has_operation ?inf_odo } . 
    OPTIONAL {?X bsc:input/sc:additionalType ?in_data } . 
    OPTIONAL {?X bsc:input/sc:additionalType/edam:has_topic ?inf_idt } . 
    OPTIONAL {?X bsc:input/sc:additionalType/edam:has_operation ?inf_ido } . 
    OPTIONAL {?X sc:applicationSubCategory ?topic } .
    OPTIONAL {?X sc:applicationSubCategory/edam:has_operation ?inf_to } .
    OPTIONAL {?X sc:applicationSubCategory/edam:has_input ?inf_tid } .
    OPTIONAL {?X sc:applicationSubCategory/edam:has_output ?inf_tod } .
    OPTIONAL {?X sc:featureList ?operation } .
    OPTIONAL {?X sc:featureList/edam:has_topic ?inf_ot } .
    OPTIONAL {?X sc:featureList/edam:has_input ?inf_oid } .
    OPTIONAL {?X sc:featureList/edam:has_output ?inf_ood } .
}
"""

res_multiqc = full_inferred_kg.query(q).graph
print(f"MultiQC inferred knowledge graph has {len(res_multiqc)} triples")
print(res_multiqc.serialize(format="turtle"))
# Out:
# MultiQC inferred knowledge graph has 29 triples
# @prefix ns1: <http://bioschemas.org/> .
# @prefix ns2: <http://schema.org/> .
#
# <https://bio.tools/frogs> ns2:applicationSubCategory <http://edamontology.org/topic_0080>,
#         <http://edamontology.org/topic_0637>,
#         <http://edamontology.org/topic_3168>,
#         <http://edamontology.org/topic_3174>,
#         <http://edamontology.org/topic_3299>,
#         <http://edamontology.org/topic_3697> ;
#     ns2:featureList <http://edamontology.org/operation_3460> .
#
# <https://bio.tools/multiqc> ns1:input <http://edamontology.org/data_2977> ;
#     ns1:output <http://edamontology.org/data_0867>,
#         <http://edamontology.org/data_3914> ;
#     ns2:applicationSubCategory <http://edamontology.org/topic_0077>,
#         <http://edamontology.org/topic_0080>,
#         <http://edamontology.org/topic_0091>,
#         <http://edamontology.org/topic_0622>,
#         <http://edamontology.org/topic_3168> ;
#     ns2:featureList <http://edamontology.org/operation_2428>,
#         <http://edamontology.org/operation_3218> .
#
# <https://bio.tools/qiime2> ns1:input <http://edamontology.org/data_2968>,
#         <http://edamontology.org/data_2977> ;
#     ns1:output <http://edamontology.org/data_2968> ;
#     ns2:applicationSubCategory <http://edamontology.org/topic_0077>,
#         <http://edamontology.org/topic_0080>,
#         <http://edamontology.org/topic_0092>,
#         <http://edamontology.org/topic_3174>,
#         <http://edamontology.org/topic_3697>,
#         <http://edamontology.org/topic_3941> ;
#     ns2:featureList <http://edamontology.org/operation_0337>,
#         <http://edamontology.org/operation_3460>,
#         <http://edamontology.org/operation_3933> .

# %%
desc_q = """
SELECT * WHERE {
<https://bio.tools/multiqc> sc:applicationSubCategory ?inf_tt
}
"""
res = full_inferred_kg.query(desc_q)
for row in res:
    print(f"MultiQC has topic {row.inf_tt}")
# Out:
# MultiQC has topic http://edamontology.org/topic_0080
# MultiQC has topic http://edamontology.org/topic_0091
# MultiQC has topic http://edamontology.org/topic_0622
# MultiQC has topic http://edamontology.org/topic_3168

# %%
desc_q = """
DESCRIBE <http://edamontology.org/operation_2478>
"""
res = full_inferred_kg.query(desc_q).graph
print(res.serialize(format="turtle"))
# Out:
# @prefix edam: <http://edamontology.org/> .
# @prefix oboInOwl: <http://www.geneontology.org/formats/oboInOwl#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# edam:operation_2478 a owl:Class ;
#     rdfs:label "Nucleic acid sequence analysis" ;
#     edam:created_in "beta12orEarlier" ;
#     edam:has_input edam:data_2977 ;
#     edam:has_topic edam:topic_0077,
#         edam:topic_0080 ;
#     oboInOwl:hasDefinition "Analyse a nucleic acid sequence (using methods that are only applicable to nucleic acid sequences)." ;
#     oboInOwl:hasExactSynonym "Sequence analysis (nucleic acid)" ;
#     oboInOwl:hasNarrowSynonym "Nucleic acid sequence alignment analysis",
#         "Sequence alignment analysis (nucleic acid)" ;
#     oboInOwl:inSubset edam:bio,
#         edam:operations ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onProperty edam:has_topic ;
#             owl:someValuesFrom edam:topic_0077 ],
#         [ a owl:Restriction ;
#             owl:onProperty edam:has_input ;
#             owl:someValuesFrom edam:data_2977 ],
#         edam:operation_2403 .

# %%
desc_q = """
DESCRIBE <http://edamontology.org/operation_3218>
"""
res = full_inferred_kg.query(desc_q).graph
print(res.serialize(format="turtle"))
# Out:
# @prefix edam: <http://edamontology.org/> .
# @prefix oboInOwl: <http://www.geneontology.org/formats/oboInOwl#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# edam:operation_3218 a owl:Class ;
#     rdfs:label "Sequencing quality control" ;
#     edam:created_in "1.1" ;
#     edam:has_input edam:data_2977 ;
#     edam:has_topic edam:topic_0077,
#         edam:topic_0080 ;
#     oboInOwl:hasDefinition "Raw sequence data quality control." ;
#     oboInOwl:hasExactSynonym "Sequencing QC",
#         "Sequencing quality assessment" ;
#     oboInOwl:inSubset edam:bio,
#         edam:operations ;
#     rdfs:comment "Analyse raw sequence data from a sequencing pipeline and identify (and possiby fix) problems." ;
#     rdfs:subClassOf edam:operation_2428,
#         edam:operation_2478 .

# %%
# test R C hasInput D AND D hasOperation O

edam_kg = Graph()
edam_kg.parse("https://edamontology.org/EDAM.owl", format="xml")
print(f"Successfully loaded EDAM: {len(edam_kg)} triples")
# Out:
# Successfully loaded EDAM: 38792 triples

# %%
edam_kg_2 = edam_kg.query(rule_0).graph
print(f"EDAM after rule 0 has {len(edam_kg_2)} triples")
print(edam_kg_2.serialize(format="turtle"))
# Out:
# EDAM after rule 0 has 862 triples
# @prefix ns1: <http://edamontology.org/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
#
# ns1:data_0860 ns1:has_topic ns1:topic_0160 .
#
# ns1:data_0940 ns1:has_topic ns1:topic_1317 .
#
# ns1:data_0942 ns1:has_topic ns1:topic_0121 .
#
# ns1:data_0944 ns1:has_topic ns1:topic_0121 .
#
# ns1:data_0945 ns1:has_topic ns1:topic_0121 .
#
# ns1:data_0956 ns1:has_topic ns1:topic_3489 .
#
# ns1:data_0987 ns1:is_identifier_of ns1:data_0919 .
#
# ns1:data_0989 ns1:is_identifier_of ns1:data_0896 .
#
# ns1:data_0993 ns1:is_identifier_of ns1:data_2851 .
#
# ns1:data_0994 ns1:is_identifier_of ns1:data_2016 .
#
# ns1:data_1008 ns1:is_identifier_of ns1:data_1467 .
#
# ns1:data_1025 ns1:is_identifier_of ns1:data_0916 .
#
# ns1:data_1038 ns1:is_identifier_of ns1:data_1468 .
#
# ns1:data_1048 ns1:is_identifier_of ns1:data_0957 .
#
# ns1:data_1051 ns1:is_identifier_of ns1:data_0582 .
#
# ns1:data_1061 ns1:is_identifier_of ns1:data_0847 .
#
# ns1:data_1063 ns1:is_identifier_of ns1:data_2044 .
#
# ns1:data_1064 ns1:is_identifier_of ns1:data_0850 .
#
# ns1:data_1066 ns1:is_identifier_of ns1:data_0863 .
#
# ns1:data_1068 ns1:is_identifier_of ns1:data_0872 .
#
# ns1:data_1069 ns1:is_identifier_of ns1:data_0874 .
#
# ns1:data_1071 ns1:is_identifier_of ns1:data_0889 .
#
# ns1:data_1072 ns1:is_identifier_of ns1:data_0886 .
#
# ns1:data_1073 ns1:is_identifier_of ns1:data_1501 .
#
# ns1:data_1074 ns1:is_identifier_of ns1:data_0906 .
#
# ns1:data_1075 ns1:is_identifier_of ns1:data_0907 .
#
# ns1:data_1076 ns1:is_identifier_of ns1:data_1597,
#         ns1:data_1598 .
#
# ns1:data_1078 ns1:is_identifier_of ns1:data_2531 .
#
# ns1:data_1079 ns1:is_identifier_of ns1:data_3805 .
#
# ns1:data_1080 ns1:is_identifier_of ns1:data_3111 .
#
# ns1:data_1081 ns1:is_identifier_of ns1:data_0920 .
#
# ns1:data_1082 ns1:is_identifier_of ns1:data_2600 .
#
# ns1:data_1085 ns1:is_identifier_of ns1:data_0950 .
#
# ns1:data_1086 ns1:is_identifier_of ns1:data_0962 .
#
# ns1:data_1088 ns1:is_identifier_of ns1:data_0971 .
#
# ns1:data_1096 ns1:is_identifier_of ns1:data_2976 .
#
# ns1:data_1097 ns1:is_identifier_of ns1:data_2977 .
#
# ns1:data_1112 ns1:is_identifier_of ns1:data_1235 .
#
# ns1:data_1114 ns1:is_identifier_of ns1:data_1353 .
#
# ns1:data_1115 ns1:is_identifier_of ns1:data_1354 .
#
# ns1:data_1118 ns1:is_identifier_of ns1:data_1364 .
#
# ns1:data_1126 ns1:is_identifier_of ns1:data_0874 .
#
# ns1:data_1132 ns1:is_identifier_of ns1:data_1355 .
#
# ns1:data_1133 ns1:is_identifier_of ns1:data_1355 .
#
# ns1:data_1134 ns1:is_identifier_of ns1:data_1355 .
#
# ns1:data_1162 ns1:is_identifier_of ns1:data_0957 .
#
# ns1:data_1163 ns1:is_identifier_of ns1:data_0957 .
#
# ns1:data_1164 ns1:is_identifier_of ns1:data_0957 .
#
# ns1:data_1463 ns1:has_topic ns1:topic_0154 .
#
# ns1:data_1696 ns1:has_topic ns1:topic_0154 .
#
# ns1:data_1713 ns1:has_topic ns1:topic_3065 .
#
# ns1:data_1869 ns1:is_identifier_of ns1:data_2530 .
#
# ns1:data_1893 ns1:is_identifier_of ns1:data_2012 .
#
# ns1:data_2019 ns1:has_topic ns1:topic_0102 .
#
# ns1:data_2108 ns1:is_identifier_of ns1:data_2978 .
#
# ns1:data_2110 ns1:is_identifier_of ns1:data_2087 .
#
# ns1:data_2111 ns1:is_identifier_of ns1:data_1597,
#         ns1:data_1598 .
#
# ns1:data_2117 ns1:is_identifier_of ns1:data_1274 .
#
# ns1:data_2119 ns1:is_identifier_of ns1:data_2084 .
#
# ns1:data_2127 ns1:is_identifier_of ns1:data_1598 .
#
# ns1:data_2223 ns1:has_topic ns1:topic_0089 .
#
# ns1:data_2291 ns1:is_identifier_of ns1:data_0849 .
#
# ns1:data_2338 ns1:is_identifier_of ns1:data_0582 .
#
# ns1:data_2353 ns1:has_topic ns1:topic_0089 .
#
# ns1:data_2355 ns1:is_identifier_of ns1:data_2354 .
#
# ns1:data_2362 ns1:is_identifier_of ns1:data_0849 .
#
# ns1:data_2382 ns1:is_identifier_of ns1:data_2531 .
#
# ns1:data_2526 ns1:has_topic ns1:topic_3068 .
#
# ns1:data_2576 ns1:is_identifier_of ns1:data_2852 .
#
# ns1:data_2611 ns1:is_identifier_of ns1:data_1622 .
#
# ns1:data_2663 ns1:is_identifier_of ns1:data_1462,
#         ns1:data_2313 .
#
# ns1:data_2762 ns1:has_topic ns1:topic_0160 .
#
# ns1:data_2769 ns1:is_identifier_of ns1:data_1276 .
#
# ns1:data_2800 ns1:is_identifier_of ns1:data_1622 .
#
# ns1:data_2812 ns1:is_identifier_of ns1:data_2850,
#         ns1:data_2879 .
#
# ns1:data_2912 ns1:is_identifier_of ns1:data_0963 .
#
# ns1:data_3025 ns1:is_identifier_of ns1:data_2858 .
#
# ns1:data_3028 ns1:has_topic ns1:topic_0084 .
#
# ns1:data_3034 ns1:is_identifier_of ns1:data_1255 .
#
# ns1:data_3035 ns1:is_identifier_of ns1:data_0883 .
#
# ns1:data_3036 ns1:is_identifier_of ns1:data_2082 .
#
# ns1:data_3273 ns1:is_identifier_of ns1:data_3113 .
#
# ns1:data_3442 ns1:has_topic ns1:topic_3384 .
#
# ns1:data_3449 ns1:has_topic ns1:topic_2229 .
#
# ns1:data_3667 ns1:is_identifier_of ns1:data_1622 .
#
# ns1:data_3806 ns1:has_topic ns1:topic_1317 .
#
# ns1:data_3807 ns1:has_topic ns1:topic_1317 .
#
# ns1:data_3808 ns1:has_topic ns1:topic_1317 .
#
# ns1:data_3842 ns1:has_topic ns1:topic_0081 .
#
# ns1:data_3953 ns1:has_topic ns1:topic_1775 .
#
# ns1:format_1475 ns1:is_format_of ns1:data_0883,
#         ns1:data_3870 .
#
# ns1:format_1637 ns1:is_format_of ns1:data_1714 .
#
# ns1:format_1638 ns1:is_format_of ns1:data_3110 .
#
# ns1:format_1644 ns1:is_format_of ns1:data_3111 .
#
# ns1:format_1919 ns1:is_format_of ns1:data_0849 .
#
# ns1:format_1920 ns1:is_format_of ns1:data_1255 .
#
# ns1:format_1921 ns1:is_format_of ns1:data_0863 .
#
# ns1:format_2006 ns1:is_format_of ns1:data_0872 .
#
# ns1:format_2013 ns1:is_format_of ns1:data_2600 .
#
# ns1:format_2014 ns1:is_format_of ns1:data_0858 .
#
# ns1:format_2017 ns1:is_format_of ns1:data_1501 .
#
# ns1:format_2020 ns1:is_format_of ns1:data_0971 .
#
# ns1:format_2021 ns1:is_format_of ns1:data_0972 .
#
# ns1:format_2027 ns1:is_format_of ns1:data_2024 .
#
# ns1:format_2030 ns1:is_format_of ns1:data_0962 .
#
# ns1:format_2031 ns1:is_format_of ns1:data_0916 .
#
# ns1:format_2035 ns1:is_format_of ns1:data_0846 .
#
# ns1:format_2036 ns1:is_format_of ns1:data_0871 .
#
# ns1:format_2037 ns1:is_format_of ns1:data_1426 .
#
# ns1:format_2038 ns1:is_format_of ns1:data_1427 .
#
# ns1:format_2039 ns1:is_format_of ns1:data_1428 .
#
# ns1:format_2040 ns1:is_format_of ns1:data_1429 .
#
# ns1:format_2049 ns1:is_format_of ns1:data_1442 .
#
# ns1:format_2052 ns1:is_format_of ns1:data_0907 .
#
# ns1:format_2054 ns1:is_format_of ns1:data_0906 .
#
# ns1:format_2055 ns1:is_format_of ns1:data_0925 .
#
# ns1:format_2057 ns1:is_format_of ns1:data_0924 .
#
# ns1:format_2058 ns1:is_format_of ns1:data_2603 .
#
# ns1:format_2060 ns1:is_format_of ns1:data_1274 .
#
# ns1:format_2062 ns1:is_format_of ns1:data_0896 .
#
# ns1:format_2064 ns1:is_format_of ns1:data_1499 .
#
# ns1:format_2065 ns1:is_format_of ns1:data_1539 .
#
# ns1:format_2066 ns1:is_format_of ns1:data_0857 .
#
# ns1:format_2067 ns1:is_format_of ns1:data_0870 .
#
# ns1:format_2068 ns1:is_format_of ns1:data_1353 .
#
# ns1:format_2069 ns1:is_format_of ns1:data_1354 .
#
# ns1:format_2072 ns1:is_format_of ns1:data_1364 .
#
# ns1:format_2074 ns1:is_format_of ns1:data_1347 .
#
# ns1:format_2075 ns1:is_format_of ns1:data_3354,
#         ns1:data_3355 .
#
# ns1:format_2076 ns1:is_format_of ns1:data_0880 .
#
# ns1:format_2078 ns1:is_format_of ns1:data_1017 .
#
# ns1:format_2170 ns1:is_format_of ns1:data_1235 .
#
# ns1:format_2195 ns1:is_format_of ns1:data_0582 .
#
# ns1:format_2331 ns1:is_format_of ns1:data_2048 .
#
# ns1:format_2352 ns1:is_format_of ns1:data_0863,
#         ns1:data_1255,
#         ns1:data_1772,
#         ns1:data_2044,
#         ns1:data_3108 .
#
# ns1:format_2548 ns1:is_format_of ns1:data_1255 .
#
# ns1:format_2571 ns1:is_format_of ns1:data_2044 .
#
# ns1:format_2848 ns1:is_format_of ns1:data_0970,
#         ns1:data_2849 .
#
# ns1:format_2919 ns1:is_format_of ns1:data_3002 .
#
# ns1:format_2920 ns1:is_format_of ns1:data_1381 .
#
# ns1:format_2921 ns1:is_format_of ns1:data_3498 .
#
# ns1:format_3033 ns1:is_format_of ns1:data_2082 .
#
# ns1:format_3097 ns1:is_format_of ns1:data_0907 .
#
# ns1:format_3161 ns1:is_format_of ns1:data_3111 .
#
# ns1:format_3162 ns1:is_format_of ns1:data_3111 .
#
# ns1:format_3166 ns1:is_format_of ns1:data_2984 .
#
# ns1:format_3167 ns1:is_format_of ns1:data_2531 .
#
# ns1:format_3235 ns1:is_format_of ns1:data_3236 .
#
# ns1:format_3245 ns1:is_format_of ns1:data_2536 .
#
# ns1:format_3326 ns1:is_format_of ns1:data_0955 .
#
# ns1:format_3327 ns1:is_format_of ns1:data_0955 .
#
# ns1:format_3484 ns1:is_format_of ns1:data_3210 .
#
# ns1:format_3491 ns1:is_format_of ns1:data_3210 .
#
# ns1:format_3547 ns1:is_format_of ns1:data_2968 .
#
# ns1:format_3578 ns1:is_format_of ns1:data_3110 .
#
# ns1:format_3606 ns1:is_format_of ns1:data_2048 .
#
# ns1:format_3616 ns1:is_format_of ns1:data_0955 .
#
# ns1:format_3626 ns1:is_format_of ns1:data_1499 .
#
# ns1:format_3681 ns1:has_topic ns1:topic_0121 .
#
# ns1:format_3706 ns1:is_format_of ns1:data_3707 .
#
# ns1:format_3708 ns1:is_format_of ns1:data_3707 .
#
# ns1:format_3772 ns1:is_format_of ns1:data_0863,
#         ns1:data_1255,
#         ns1:data_1772,
#         ns1:data_2044,
#         ns1:data_3108 .
#
# ns1:format_3773 ns1:is_format_of ns1:data_0863,
#         ns1:data_1255,
#         ns1:data_1772,
#         ns1:data_2044,
#         ns1:data_3108 .
#
# ns1:format_3774 ns1:is_format_of ns1:data_0863,
#         ns1:data_1255 .
#
# ns1:format_3777 ns1:is_format_of ns1:data_2530,
#         ns1:data_3113,
#         ns1:data_3567 .
#
# ns1:format_3780 ns1:is_format_of ns1:data_3779 .
#
# ns1:format_3787 ns1:is_format_of ns1:data_3786 .
#
# ns1:format_3824 ns1:is_format_of ns1:data_3488 .
#
# ns1:format_3828 ns1:is_format_of ns1:data_3110 .
#
# ns1:format_3866 ns1:is_format_of ns1:data_3870 .
#
# ns1:format_3879 ns1:is_format_of ns1:data_3872 .
#
# ns1:format_3884 ns1:is_format_of ns1:data_3872 .
#
# ns1:format_3909 ns1:is_format_of ns1:data_1255 .
#
# ns1:format_3911 ns1:is_format_of ns1:data_2190 .
#
# ns1:format_3913 ns1:is_format_of ns1:data_2535,
#         ns1:data_3112 .
#
# ns1:format_3915 ns1:is_format_of ns1:data_2535,
#         ns1:data_3112 .
#
# ns1:format_3916 ns1:is_format_of ns1:data_2535,
#         ns1:data_3112 .
#
# ns1:format_3971 ns1:is_format_of ns1:data_3241 .
#
# ns1:format_3972 ns1:is_format_of ns1:data_3241 .
#
# ns1:format_4015 ns1:is_format_of ns1:data_3869 .
#
# ns1:format_4024 ns1:is_format_of ns1:data_0883 .
#
# ns1:format_4041 ns1:is_format_of ns1:data_4040 .
#
# ns1:format_4050 ns1:is_format_of ns1:data_2531 .
#
# ns1:format_4058 ns1:has_topic ns1:topic_3172 .
#
# ns1:format_4059 ns1:has_topic ns1:topic_0153 .
#
# ns1:operation_0226 ns1:has_input ns1:data_0582 ;
#     ns1:has_topic ns1:topic_0089 .
#
# ns1:operation_0227 ns1:has_output ns1:data_0955 .
#
# ns1:operation_0234 ns1:has_output ns1:data_1259 ;
#     ns1:has_topic ns1:topic_0157 .
#
# ns1:operation_0235 ns1:has_output ns1:data_1260 ;
#     ns1:has_topic ns1:topic_0157 .
#
# ns1:operation_0236 ns1:has_output ns1:data_1261 ;
#     ns1:has_topic ns1:topic_0157 .
#
# ns1:operation_0237 ns1:has_topic ns1:topic_0157 .
#
# ns1:operation_0238 ns1:has_output ns1:data_0858 ;
#     ns1:has_topic ns1:topic_0160 .
#
# ns1:operation_0239 ns1:has_output ns1:data_0858 ;
#     ns1:has_topic ns1:topic_0160 .
#
# ns1:operation_0240 ns1:has_output ns1:data_0858 ;
#     ns1:has_topic ns1:topic_0160 .
#
# ns1:operation_0245 ns1:has_topic ns1:topic_0166 .
#
# ns1:operation_0246 ns1:has_topic ns1:topic_0736 .
#
# ns1:operation_0248 ns1:has_topic ns1:topic_0130 .
#
# ns1:operation_0249 ns1:has_output ns1:data_2991 .
#
# ns1:operation_0252 ns1:has_output ns1:data_1534 ;
#     ns1:has_topic ns1:topic_0804 .
#
# ns1:operation_0253 ns1:has_output ns1:data_1255 ;
#     ns1:has_topic ns1:topic_0160 .
#
# ns1:operation_0256 ns1:has_input ns1:data_1255 ;
#     ns1:has_topic ns1:topic_0160 .
#
# ns1:operation_0258 ns1:has_input ns1:data_0863 .
#
# ns1:operation_0262 ns1:has_output ns1:data_0912 .
#
# ns1:operation_0264 ns1:has_topic ns1:topic_0114 .
#
# ns1:operation_0265 ns1:has_topic ns1:topic_3168 .
#
# ns1:operation_0268 ns1:has_output ns1:data_1277 .
#
# ns1:operation_0270 ns1:has_topic ns1:topic_0820 .
#
# ns1:operation_0272 ns1:has_topic ns1:topic_0130 .
#
# ns1:operation_0276 ns1:has_output ns1:data_2984 ;
#     ns1:has_topic ns1:topic_0128 .
#
# ns1:operation_0278 ns1:has_output ns1:data_0880 .
#
# ns1:operation_0279 ns1:has_output ns1:data_1596 .
#
# ns1:operation_0282 ns1:has_output ns1:data_1278 .
#
# ns1:operation_0283 ns1:has_output ns1:data_0927 ;
#     ns1:has_topic ns1:topic_0102 .
#
# ns1:operation_0284 ns1:has_output ns1:data_1597 .
#
# ns1:operation_0286 ns1:has_input ns1:data_1597,
#         ns1:data_2977 ;
#     ns1:has_output ns1:data_0914,
#         ns1:data_1597 ;
#     ns1:has_topic ns1:topic_0203 .
#
# ns1:operation_0287 ns1:has_output ns1:data_1263 ;
#     ns1:has_topic ns1:topic_0114 .
#
# ns1:operation_0289 ns1:has_output ns1:data_0870 ;
#     ns1:has_topic ns1:topic_0084 .
#
# ns1:operation_0290 ns1:has_output ns1:data_2044 .
#
# ns1:operation_0291 ns1:has_output ns1:data_1235 .
#
# ns1:operation_0292 ns1:has_output ns1:data_0863 .
#
# ns1:operation_0295 ns1:has_output ns1:data_0886 .
#
# ns1:operation_0296 ns1:has_input ns1:data_0863 ;
#     ns1:has_output ns1:data_1354 ;
#     ns1:has_topic ns1:topic_0160 .
#
# ns1:operation_0297 ns1:has_input ns1:data_0883,
#         ns1:data_0886 ;
#     ns1:has_output ns1:data_0889 .
#
# ns1:operation_0300 ns1:has_input ns1:data_1354 ;
#     ns1:has_topic ns1:topic_0160 .
#
# ns1:operation_0302 ns1:has_input ns1:data_1460 ;
#     ns1:has_output ns1:data_0893 .
#
# ns1:operation_0305 ns1:has_topic ns1:topic_3068 .
#
# ns1:operation_0306 ns1:has_input ns1:data_3671 ;
#     ns1:has_output ns1:data_0972 ;
#     ns1:has_topic ns1:topic_0218 .
#
# ns1:operation_0308 ns1:has_input ns1:data_2977 ;
#     ns1:has_output ns1:data_1240 ;
#     ns1:has_topic ns1:topic_0632 .
#
# ns1:operation_0309 ns1:has_input ns1:data_2977 ;
#     ns1:has_output ns1:data_2717 ;
#     ns1:has_topic ns1:topic_0203,
#         ns1:topic_0632 .
#
# ns1:operation_0310 ns1:has_output ns1:data_0925 ;
#     ns1:has_topic ns1:topic_0196 .
#
# ns1:operation_0313 ns1:has_output ns1:data_3111 .
#
# ns1:operation_0319 ns1:has_topic ns1:topic_1317,
#         ns1:topic_2814 .
#
# ns1:operation_0320 ns1:has_output ns1:data_1460 ;
#     ns1:has_topic ns1:topic_1317 .
#
# ns1:operation_0321 ns1:has_output ns1:data_1539 ;
#     ns1:has_topic ns1:topic_2275 .
#
# ns1:operation_0323 ns1:has_output ns1:data_0872 ;
#     ns1:has_topic ns1:topic_0080 .
#
# ns1:operation_0324 ns1:has_topic ns1:topic_0084 .
#
# ns1:operation_0326 ns1:has_input ns1:data_0872 ;
#     ns1:has_output ns1:data_0872 .
#
# ns1:operation_0327 ns1:has_topic ns1:topic_0194 .
#
# ns1:operation_0331 ns1:has_topic ns1:topic_0130,
#         ns1:topic_0199 .
#
# ns1:operation_0334 ns1:has_output ns1:data_2024 ;
#     ns1:has_topic ns1:topic_0821 .
#
# ns1:operation_0337 ns1:has_input ns1:data_2968 ;
#     ns1:has_output ns1:data_2968 ;
#     ns1:has_topic ns1:topic_0092 .
#
# ns1:operation_0338 ns1:has_output ns1:data_0857 .
#
# ns1:operation_0339 ns1:has_topic ns1:topic_0081 .
#
# ns1:operation_0361 ns1:has_input ns1:data_0849 ;
#     ns1:has_output ns1:data_0849 .
#
# ns1:operation_0365 ns1:has_output ns1:data_1239 .
#
# ns1:operation_0366 ns1:has_output ns1:data_1238 ;
#     ns1:has_topic ns1:topic_0121 .
#
# ns1:operation_0371 ns1:has_topic ns1:topic_0108 .
#
# ns1:operation_0372 ns1:has_topic ns1:topic_0203 .
#
# ns1:operation_0384 ns1:has_output ns1:data_1542 .
#
# ns1:operation_0386 ns1:has_output ns1:data_1545 .
#
# ns1:operation_0389 ns1:has_topic ns1:topic_0128 .
#
# ns1:operation_0391 ns1:has_output ns1:data_1546 .
#
# ns1:operation_0392 ns1:has_output ns1:data_1547 .
#
# ns1:operation_0393 ns1:has_output ns1:data_1548 .
#
# ns1:operation_0394 ns1:has_output ns1:data_1549 .
#
# ns1:operation_0396 ns1:has_output ns1:data_1544 .
#
# ns1:operation_0398 ns1:has_output ns1:data_1519 ;
#     ns1:has_topic ns1:topic_0121 .
#
# ns1:operation_0399 ns1:has_output ns1:data_1531 .
#
# ns1:operation_0400 ns1:has_output ns1:data_0897 ;
#     ns1:has_topic ns1:topic_0123 .
#
# ns1:operation_0402 ns1:has_output ns1:data_1527 .
#
# ns1:operation_0403 ns1:has_output ns1:data_1528 .
#
# ns1:operation_0404 ns1:has_output ns1:data_1530 .
#
# ns1:operation_0406 ns1:has_output ns1:data_1521 .
#
# ns1:operation_0407 ns1:has_output ns1:data_1520 .
#
# ns1:operation_0408 ns1:has_output ns1:data_1526 .
#
# ns1:operation_0409 ns1:has_output ns1:data_1524 .
#
# ns1:operation_0410 ns1:has_output ns1:data_1525 .
#
# ns1:operation_0415 ns1:has_output ns1:data_1276 ;
#     ns1:has_topic ns1:topic_0160 .
#
# ns1:operation_0416 ns1:has_topic ns1:topic_0804 .
#
# ns1:operation_0417 ns1:has_topic ns1:topic_0601 .
#
# ns1:operation_0418 ns1:has_topic ns1:topic_0140 .
#
# ns1:operation_0422 ns1:has_topic ns1:topic_0121 .
#
# ns1:operation_0429 ns1:has_output ns1:data_3128 .
#
# ns1:operation_0430 ns1:has_topic ns1:topic_0157 .
#
# ns1:operation_0431 ns1:has_topic ns1:topic_0160 .
#
# ns1:operation_0433 ns1:has_topic ns1:topic_0114 .
#
# ns1:operation_0437 ns1:has_output ns1:data_0916 .
#
# ns1:operation_0438 ns1:has_topic ns1:topic_0749 .
#
# ns1:operation_0439 ns1:has_topic ns1:topic_0108 .
#
# ns1:operation_0443 ns1:has_topic ns1:topic_0659 .
#
# ns1:operation_0446 ns1:has_topic ns1:topic_0114 .
#
# ns1:operation_0455 ns1:has_output ns1:data_2985 .
#
# ns1:operation_0456 ns1:has_output ns1:data_1583 .
#
# ns1:operation_0461 ns1:has_output ns1:data_0912 .
#
# ns1:operation_0464 ns1:has_topic ns1:topic_0659 .
#
# ns1:operation_0465 ns1:has_topic ns1:topic_0659 .
#
# ns1:operation_0474 ns1:has_output ns1:data_1460 .
#
# ns1:operation_0475 ns1:has_output ns1:data_1459 .
#
# ns1:operation_0477 ns1:has_topic ns1:topic_2275 .
#
# ns1:operation_0478 ns1:has_output ns1:data_1461,
#         ns1:data_2877 .
#
# ns1:operation_0482 ns1:has_output ns1:data_1461 ;
#     ns1:has_topic ns1:topic_0128 .
#
# ns1:operation_0483 ns1:has_output ns1:data_1234 .
#
# ns1:operation_0485 ns1:has_output ns1:data_2870 .
#
# ns1:operation_0487 ns1:has_output ns1:data_1863 .
#
# ns1:operation_0488 ns1:has_output ns1:data_0927 .
#
# ns1:operation_0489 ns1:has_output ns1:data_1598 .
#
# ns1:operation_0490 ns1:has_output ns1:data_0862 .
#
# ns1:operation_0491 ns1:has_output ns1:data_1381 .
#
# ns1:operation_0499 ns1:has_topic ns1:topic_0084 .
#
# ns1:operation_0502 ns1:has_input ns1:data_0880 ;
#     ns1:has_output ns1:data_0881 .
#
# ns1:operation_0531 ns1:has_output ns1:data_1636 .
#
# ns1:operation_0533 ns1:has_output ns1:data_2984 .
#
# ns1:operation_0541 ns1:has_input ns1:data_1426 .
#
# ns1:operation_0542 ns1:has_input ns1:data_2873 ;
#     ns1:has_topic ns1:topic_0203 .
#
# ns1:operation_0543 ns1:has_topic ns1:topic_0199 .
#
# ns1:operation_0550 ns1:has_output ns1:data_1439 ;
#     ns1:has_topic ns1:topic_0084 .
#
# ns1:operation_0553 ns1:has_output ns1:data_0916 ;
#     ns1:has_topic ns1:topic_0194 .
#
# ns1:operation_0557 ns1:has_output ns1:data_1442 .
#
# ns1:operation_0560 ns1:has_topic ns1:topic_0804 .
#
# ns1:operation_0564 ns1:has_input ns1:data_2044 ;
#     ns1:has_output ns1:data_2969 .
#
# ns1:operation_0566 ns1:has_input ns1:data_1235 .
#
# ns1:operation_0567 ns1:has_output ns1:data_0872 .
#
# ns1:operation_0570 ns1:has_input ns1:data_0883 ;
#     ns1:has_output ns1:data_1710 .
#
# ns1:operation_0571 ns1:has_input ns1:data_3117 .
#
# ns1:operation_0573 ns1:has_input ns1:data_1274 .
#
# ns1:operation_0575 ns1:has_output ns1:data_1289 .
#
# ns1:operation_0579 ns1:has_topic ns1:topic_0114 .
#
# ns1:operation_1777 ns1:has_topic ns1:topic_1775 .
#
# ns1:operation_1778 ns1:has_topic ns1:topic_1775 .
#
# ns1:operation_1781 ns1:has_topic ns1:topic_0602 .
#
# ns1:operation_1850 ns1:has_topic ns1:topic_0130 .
#
# ns1:operation_2008 ns1:has_topic ns1:topic_0659 .
#
# ns1:operation_2239 ns1:has_output ns1:data_1499 ;
#     ns1:has_topic ns1:topic_0081 .
#
# ns1:operation_2241 ns1:has_output ns1:data_2992 .
#
# ns1:operation_2403 ns1:has_topic ns1:topic_0080 .
#
# ns1:operation_2406 ns1:has_input ns1:data_1460 ;
#     ns1:has_topic ns1:topic_2814 .
#
# ns1:operation_2409 ns1:has_topic ns1:topic_3489 .
#
# ns1:operation_2415 ns1:has_output ns1:data_1537 ;
#     ns1:has_topic ns1:topic_0130 .
#
# ns1:operation_2416 ns1:has_output ns1:data_2956 ;
#     ns1:has_topic ns1:topic_2814 .
#
# ns1:operation_2419 ns1:has_topic ns1:topic_0632 .
#
# ns1:operation_2421 ns1:has_output ns1:data_2080 .
#
# ns1:operation_2422 ns1:has_input ns1:data_0842 .
#
# ns1:operation_2426 ns1:has_topic ns1:topic_2275 .
#
# ns1:operation_2436 ns1:has_output ns1:data_3754 ;
#     ns1:has_topic ns1:topic_1775 .
#
# ns1:operation_2439 ns1:has_topic ns1:topic_0097 .
#
# ns1:operation_2441 ns1:has_output ns1:data_1465 .
#
# ns1:operation_2442 ns1:has_output ns1:data_1464 .
#
# ns1:operation_2451 ns1:has_input ns1:data_2044 ;
#     ns1:has_output ns1:data_2955 .
#
# ns1:operation_2454 ns1:has_output ns1:data_0916 ;
#     ns1:has_topic ns1:topic_0114 .
#
# ns1:operation_2464 ns1:has_output ns1:data_0906 ;
#     ns1:has_topic ns1:topic_0128 .
#
# ns1:operation_2476 ns1:has_output ns1:data_0883 ;
#     ns1:has_topic ns1:topic_0082,
#         ns1:topic_0176 .
#
# ns1:operation_2478 ns1:has_input ns1:data_2977 ;
#     ns1:has_topic ns1:topic_0077 .
#
# ns1:operation_2479 ns1:has_input ns1:data_2976 ;
#     ns1:has_topic ns1:topic_0078 .
#
# ns1:operation_2480 ns1:has_topic ns1:topic_0081 .
#
# ns1:operation_2481 ns1:has_input ns1:data_1459 ;
#     ns1:has_topic ns1:topic_0097 .
#
# ns1:operation_2483 ns1:has_topic ns1:topic_0081 .
#
# ns1:operation_2485 ns1:has_output ns1:data_2162 .
#
# ns1:operation_2486 ns1:has_output ns1:data_2992 .
#
# ns1:operation_2487 ns1:has_input ns1:data_1460 .
#
# ns1:operation_2489 ns1:has_topic ns1:topic_0140 .
#
# ns1:operation_2492 ns1:has_output ns1:data_0906 ;
#     ns1:has_topic ns1:topic_0128 .
#
# ns1:operation_2495 ns1:has_topic ns1:topic_0203 .
#
# ns1:operation_2499 ns1:has_topic ns1:topic_0114 .
#
# ns1:operation_2510 ns1:has_topic ns1:topic_0108 .
#
# ns1:operation_2520 ns1:has_output ns1:data_1274 ;
#     ns1:has_topic ns1:topic_0102,
#         ns1:topic_0196 .
#
# ns1:operation_2574 ns1:has_output ns1:data_2970 ;
#     ns1:has_topic ns1:topic_0123 .
#
# ns1:operation_2575 ns1:has_topic ns1:topic_0128 .
#
# ns1:operation_2871 ns1:has_output ns1:data_1279 .
#
# ns1:operation_2930 ns1:has_output ns1:data_0897 .
#
# ns1:operation_2944 ns1:has_output ns1:data_1280 ;
#     ns1:has_topic ns1:topic_0102 .
#
# ns1:operation_2949 ns1:has_output ns1:data_0906 ;
#     ns1:has_topic ns1:topic_0128 .
#
# ns1:operation_2962 ns1:has_output ns1:data_2865 .
#
# ns1:operation_2964 ns1:has_output ns1:data_1602 .
#
# ns1:operation_3080 ns1:has_input ns1:data_0883 .
#
# ns1:operation_3092 ns1:has_output ns1:data_1277 ;
#     ns1:has_topic ns1:topic_0078,
#         ns1:topic_0160 .
#
# ns1:operation_3180 ns1:has_input ns1:data_0925 ;
#     ns1:has_output ns1:data_3181 ;
#     ns1:has_topic ns1:topic_0196 .
#
# ns1:operation_3185 ns1:has_topic ns1:topic_3168 .
#
# ns1:operation_3195 ns1:has_topic ns1:topic_3168 .
#
# ns1:operation_3211 ns1:has_output ns1:data_3210 .
#
# ns1:operation_3214 ns1:has_topic ns1:topic_0121 .
#
# ns1:operation_3215 ns1:has_input ns1:data_0943 .
#
# ns1:operation_3216 ns1:has_topic ns1:topic_0077 .
#
# ns1:operation_3221 ns1:has_topic ns1:topic_3174 .
#
# ns1:operation_3258 ns1:has_output ns1:data_0925 ;
#     ns1:has_topic ns1:topic_0196 .
#
# ns1:operation_3267 ns1:has_input ns1:data_2012 ;
#     ns1:has_output ns1:data_2012 .
#
# ns1:operation_3348 ns1:has_input ns1:data_2044 ;
#     ns1:has_topic ns1:topic_3077 .
#
# ns1:operation_3349 ns1:has_output ns1:data_3505 .
#
# ns1:operation_3351 ns1:has_topic ns1:topic_0123,
#         ns1:topic_0166 .
#
# ns1:operation_3357 ns1:has_output ns1:data_3358 .
#
# ns1:operation_3431 ns1:has_topic ns1:topic_0219 .
#
# ns1:operation_3437 ns1:has_topic ns1:topic_3068 .
#
# ns1:operation_3443 ns1:has_topic ns1:topic_3382 .
#
# ns1:operation_3446 ns1:has_topic ns1:topic_2229 .
#
# ns1:operation_3450 ns1:has_topic ns1:topic_2229 .
#
# ns1:operation_3457 ns1:has_topic ns1:topic_1317 .
#
# ns1:operation_3459 ns1:has_topic ns1:topic_1775 .
#
# ns1:operation_3461 ns1:has_topic ns1:topic_3301 .
#
# ns1:operation_3465 ns1:has_topic ns1:topic_0121 .
#
# ns1:operation_3469 ns1:has_topic ns1:topic_0097 .
#
# ns1:operation_3478 ns1:has_topic ns1:topic_0084 .
#
# ns1:operation_3482 ns1:has_topic ns1:topic_3301 .
#
# ns1:operation_3501 ns1:has_output ns1:data_3753 .
#
# ns1:operation_3502 ns1:has_topic ns1:topic_1775 .
#
# ns1:operation_3552 ns1:has_topic ns1:topic_3382 .
#
# ns1:operation_3627 ns1:has_input ns1:data_0943 .
#
# ns1:operation_3628 ns1:has_input ns1:data_0943 .
#
# ns1:operation_3629 ns1:has_input ns1:data_0943 .
#
# ns1:operation_3630 ns1:has_input ns1:data_0943 .
#
# ns1:operation_3631 ns1:has_input ns1:data_0943 .
#
# ns1:operation_3632 ns1:has_input ns1:data_0943 ;
#     ns1:has_topic ns1:topic_0121 .
#
# ns1:operation_3660 ns1:has_topic ns1:topic_2259 .
#
# ns1:operation_3766 ns1:has_topic ns1:topic_0602 .
#
# ns1:operation_3767 ns1:has_input ns1:data_0943 .
#
# ns1:operation_3778 ns1:has_input ns1:data_3671 ;
#     ns1:has_output ns1:data_3779 ;
#     ns1:has_topic ns1:topic_3068 .
#
# ns1:operation_3801 ns1:has_input ns1:data_0943 .
#
# ns1:operation_3860 ns1:has_input ns1:data_0943 .
#
# ns1:operation_3890 ns1:has_output ns1:data_2162 .
#
# ns1:operation_3893 ns1:has_output ns1:data_1439 ;
#     ns1:has_topic ns1:topic_0084 .
#
# ns1:operation_3899 ns1:has_output ns1:data_1461 ;
#     ns1:has_topic ns1:topic_0128 .
#
# ns1:operation_3900 ns1:has_output ns1:data_0906 ;
#     ns1:has_topic ns1:topic_0128 .
#
# ns1:operation_3901 ns1:has_output ns1:data_0906 ;
#     ns1:has_topic ns1:topic_0128 .
#
# ns1:operation_3904 ns1:has_topic ns1:topic_3301 .
#
# ns1:operation_3918 ns1:has_topic ns1:topic_0622 .
#
# ns1:operation_3920 ns1:has_topic ns1:topic_0622 .
#
# ns1:operation_3925 ns1:has_input ns1:data_2600 .
#
# ns1:operation_3926 ns1:has_input ns1:data_2600 .
#
# ns1:operation_3927 ns1:has_topic ns1:topic_0602,
#         ns1:topic_2259 .
#
# ns1:operation_3928 ns1:has_topic ns1:topic_0602,
#         ns1:topic_2259 .
#
# ns1:operation_3935 ns1:has_input ns1:data_0943 ;
#     ns1:has_topic ns1:topic_0121 .
#
# ns1:operation_3936 ns1:has_input ns1:data_0943 ;
#     ns1:has_topic ns1:topic_0121 .
#
# ns1:operation_3937 ns1:has_input ns1:data_0943 ;
#     ns1:has_topic ns1:topic_0121 .
#
# ns1:operation_3938 ns1:has_output ns1:data_1461 ;
#     ns1:has_topic ns1:topic_0128 .
#
# ns1:operation_3946 ns1:has_output ns1:data_1439 ;
#     ns1:has_topic ns1:topic_0084 .
#
# ns1:operation_3968 ns1:has_topic ns1:topic_0804 .
#
# ns1:operation_4031 ns1:has_input ns1:data_2042 ;
#     ns1:has_output ns1:data_0951 ;
#     ns1:has_topic ns1:topic_2269,
#         ns1:topic_3365,
#         ns1:topic_3572 .
#
# ns1:operation_4032 ns1:has_input ns1:data_3494 ;
#     ns1:has_output ns1:data_1276,
#         ns1:data_1772 ;
#     ns1:has_topic ns1:topic_0160,
#         ns1:topic_3295 .
#
# ns1:operation_4033 ns1:has_output ns1:data_2048 ;
#     ns1:has_topic ns1:topic_3305,
#         ns1:topic_3324 .
#
# ns1:operation_4034 ns1:has_input ns1:data_1669 ;
#     ns1:has_output ns1:data_3932 ;
#     ns1:has_topic ns1:topic_2269 .
#
# ns1:operation_4042 ns1:has_output ns1:data_4040 ;
#     ns1:has_topic ns1:topic_3071 .
#
# ns1:operation_4043 ns1:has_topic ns1:topic_4011 .
#
# ns1:topic_4038 skos:related ns1:topic_3923 .
#
# ns1:data_0006 a owl:Class .
#
# ns1:data_0842 a owl:Class ;
#     ns1:is_identifier_of ns1:data_0006 .
#
# ns1:data_0846 a owl:Class .
#
# ns1:data_0847 a owl:Class .
#
# ns1:data_0850 a owl:Class .
#
# ns1:data_0862 a owl:Class .
#
# ns1:data_0871 a owl:Class .
#
# ns1:data_0881 a owl:Class .
#
# ns1:data_0893 a owl:Class .
#
# ns1:data_0914 a owl:Class ;
#     ns1:has_topic ns1:topic_0203 .
#
# ns1:data_0919 a owl:Class .
#
# ns1:data_0920 a owl:Class .
#
# ns1:data_0924 a owl:Class .
#
# ns1:data_0950 a owl:Class ;
#     ns1:has_topic ns1:topic_3307 .
#
# ns1:data_0951 a owl:Class .
#
# ns1:data_0963 a owl:Class .
#
# ns1:data_0970 a owl:Class .
#
# ns1:data_1017 a owl:Class .
#
# ns1:data_1234 a owl:Class .
#
# ns1:data_1238 a owl:Class ;
#     ns1:has_topic ns1:topic_0121 .
#
# ns1:data_1239 a owl:Class .
#
# ns1:data_1240 a owl:Class .
#
# ns1:data_1259 a owl:Class .
#
# ns1:data_1260 a owl:Class .
#
# ns1:data_1261 a owl:Class .
#
# ns1:data_1263 a owl:Class .
#
# ns1:data_1278 a owl:Class .
#
# ns1:data_1279 a owl:Class .
#
# ns1:data_1280 a owl:Class .
#
# ns1:data_1289 a owl:Class .
#
# ns1:data_1347 a owl:Class .
#
# ns1:data_1427 a owl:Class .
#
# ns1:data_1428 a owl:Class .
#
# ns1:data_1429 a owl:Class ;
#     ns1:has_topic ns1:topic_0199 .
#
# ns1:data_1462 a owl:Class ;
#     ns1:has_topic ns1:topic_0152,
#         ns1:topic_0153 .
#
# ns1:data_1464 a owl:Class .
#
# ns1:data_1465 a owl:Class ;
#     ns1:has_topic ns1:topic_0097 .
#
# ns1:data_1467 a owl:Class .
#
# ns1:data_1468 a owl:Class ;
#     ns1:has_topic ns1:topic_0736 .
#
# ns1:data_1519 a owl:Class .
#
# ns1:data_1520 a owl:Class .
#
# ns1:data_1521 a owl:Class .
#
# ns1:data_1524 a owl:Class .
#
# ns1:data_1525 a owl:Class .
#
# ns1:data_1526 a owl:Class .
#
# ns1:data_1527 a owl:Class .
#
# ns1:data_1528 a owl:Class .
#
# ns1:data_1530 a owl:Class .
#
# ns1:data_1531 a owl:Class .
#
# ns1:data_1534 a owl:Class .
#
# ns1:data_1537 a owl:Class .
#
# ns1:data_1542 a owl:Class .
#
# ns1:data_1544 a owl:Class .
#
# ns1:data_1545 a owl:Class .
#
# ns1:data_1546 a owl:Class .
#
# ns1:data_1547 a owl:Class .
#
# ns1:data_1548 a owl:Class .
#
# ns1:data_1549 a owl:Class .
#
# ns1:data_1583 a owl:Class .
#
# ns1:data_1596 a owl:Class .
#
# ns1:data_1602 a owl:Class .
#
# ns1:data_1636 a owl:Class .
#
# ns1:data_1669 a owl:Class .
#
# ns1:data_1710 a owl:Class .
#
# ns1:data_1714 a owl:Class .
#
# ns1:data_1863 a owl:Class .
#
# ns1:data_2016 a owl:Class .
#
# ns1:data_2042 a owl:Class .
#
# ns1:data_2080 a owl:Class .
#
# ns1:data_2084 a owl:Class .
#
# ns1:data_2087 a owl:Class .
#
# ns1:data_2190 a owl:Class .
#
# ns1:data_2313 a owl:Class .
#
# ns1:data_2354 a owl:Class .
#
# ns1:data_2536 a owl:Class .
#
# ns1:data_2603 a owl:Class ;
#     ns1:has_topic ns1:topic_0203 .
#
# ns1:data_2717 a owl:Class ;
#     ns1:has_topic ns1:topic_0632 .
#
# ns1:data_2849 a owl:Class .
#
# ns1:data_2850 a owl:Class .
#
# ns1:data_2851 a owl:Class .
#
# ns1:data_2852 a owl:Class .
#
# ns1:data_2858 a owl:Class .
#
# ns1:data_2865 a owl:Class .
#
# ns1:data_2870 a owl:Class .
#
# ns1:data_2873 a owl:Class .
#
# ns1:data_2877 a owl:Class .
#
# ns1:data_2879 a owl:Class .
#
# ns1:data_2955 a owl:Class .
#
# ns1:data_2956 a owl:Class .
#
# ns1:data_2969 a owl:Class .
#
# ns1:data_2970 a owl:Class .
#
# ns1:data_2978 a owl:Class .
#
# ns1:data_2985 a owl:Class .
#
# ns1:data_2991 a owl:Class .
#
# ns1:data_3002 a owl:Class .
#
# ns1:data_3117 a owl:Class .
#
# ns1:data_3128 a owl:Class .
#
# ns1:data_3181 a owl:Class .
#
# ns1:data_3236 a owl:Class .
#
# ns1:data_3354 a owl:Class .
#
# ns1:data_3355 a owl:Class .
#
# ns1:data_3358 a owl:Class .
#
# ns1:data_3488 a owl:Class ;
#     ns1:has_topic ns1:topic_1317 .
#
# ns1:data_3494 a owl:Class .
#
# ns1:data_3498 a owl:Class ;
#     ns1:has_topic ns1:topic_0199 .
#
# ns1:data_3505 a owl:Class .
#
# ns1:data_3567 a owl:Class .
#
# ns1:data_3753 a owl:Class .
#
# ns1:data_3754 a owl:Class ;
#     ns1:has_topic ns1:topic_1775 .
#
# ns1:data_3786 a owl:Class .
#
# ns1:data_3805 a owl:Class ;
#     ns1:has_topic ns1:topic_1317 .
#
# ns1:data_3869 a owl:Class .
#
# ns1:data_3932 a owl:Class .
#
# ns1:topic_0082 a owl:Class .
#
# ns1:topic_0092 a owl:Class .
#
# ns1:topic_0152 a owl:Class .
#
# ns1:topic_0176 a owl:Class .
#
# ns1:topic_0218 a owl:Class .
#
# ns1:topic_0219 a owl:Class .
#
# ns1:topic_0601 a owl:Class .
#
# ns1:topic_0634 a owl:Class .
#
# ns1:topic_0749 a owl:Class .
#
# ns1:topic_0820 a owl:Class .
#
# ns1:topic_0821 a owl:Class .
#
# ns1:topic_3065 a owl:Class .
#
# ns1:topic_3077 a owl:Class .
#
# ns1:topic_3172 a owl:Class .
#
# ns1:topic_3174 a owl:Class .
#
# ns1:topic_3295 a owl:Class .
#
# ns1:topic_3305 a owl:Class .
#
# ns1:topic_3307 a owl:Class .
#
# ns1:topic_3324 a owl:Class .
#
# ns1:topic_3365 a owl:Class .
#
# ns1:topic_3384 a owl:Class .
#
# ns1:topic_3572 a owl:Class .
#
# ns1:topic_3923 a owl:Class .
#
# ns1:topic_4011 a owl:Class .
#
# ns1:data_0857 a owl:Class .
#
# ns1:data_0870 a owl:Class .
#
# ns1:data_0874 a owl:Class .
#
# ns1:data_0889 a owl:Class ;
#     ns1:has_topic ns1:topic_0081 .
#
# ns1:data_0896 a owl:Class .
#
# ns1:data_0897 a owl:Class .
#
# ns1:data_0912 a owl:Class .
#
# ns1:data_0927 a owl:Class .
#
# ns1:data_0962 a owl:Class ;
#     ns1:has_topic ns1:topic_0154 .
#
# ns1:data_0971 a owl:Class .
#
# ns1:data_0972 a owl:Class .
#
# ns1:data_1277 a owl:Class .
#
# ns1:data_1353 a owl:Class ;
#     ns1:has_topic ns1:topic_0160 .
#
# ns1:data_1364 a owl:Class .
#
# ns1:data_1381 a owl:Class .
#
# ns1:data_1426 a owl:Class .
#
# ns1:data_1442 a owl:Class .
#
# ns1:data_1459 a owl:Class ;
#     ns1:has_topic ns1:topic_0097 .
#
# ns1:data_1501 a owl:Class .
#
# ns1:data_1539 a owl:Class .
#
# ns1:data_2024 a owl:Class .
#
# ns1:data_2082 a owl:Class .
#
# ns1:data_2162 a owl:Class .
#
# ns1:data_2530 a owl:Class .
#
# ns1:data_2976 a owl:Class .
#
# ns1:data_2992 a owl:Class .
#
# ns1:data_3113 a owl:Class .
#
# ns1:data_3241 a owl:Class .
#
# ns1:data_3671 a owl:Class .
#
# ns1:data_3707 a owl:Class .
#
# ns1:data_3779 a owl:Class .
#
# ns1:data_3870 a owl:Class .
#
# ns1:data_3872 a owl:Class .
#
# ns1:data_4040 a owl:Class ;
#     ns1:has_topic ns1:topic_3071 .
#
# ns1:topic_0077 a owl:Class .
#
# ns1:topic_0078 a owl:Class .
#
# ns1:topic_0140 a owl:Class .
#
# ns1:topic_0153 a owl:Class .
#
# ns1:topic_0166 a owl:Class .
#
# ns1:topic_0194 a owl:Class .
#
# ns1:topic_0622 a owl:Class .
#
# ns1:topic_0623 a owl:Class .
#
# ns1:topic_0736 a owl:Class .
#
# ns1:topic_2269 a owl:Class .
#
# ns1:topic_3071 a owl:Class .
#
# ns1:topic_3382 a owl:Class .
#
# ns1:data_0880 a owl:Class ;
#     ns1:has_topic ns1:topic_0097 .
#
# ns1:data_0886 a owl:Class ;
#     ns1:has_topic ns1:topic_0081 .
#
# ns1:data_0907 a owl:Class ;
#     ns1:has_topic ns1:topic_0623 .
#
# ns1:data_1276 a owl:Class .
#
# ns1:data_1355 a owl:Class .
#
# ns1:data_1439 a owl:Class .
#
# ns1:data_1499 a owl:Class .
#
# ns1:data_1622 a owl:Class ;
#     ns1:has_topic ns1:topic_0634 .
#
# ns1:data_2012 a owl:Class .
#
# ns1:data_2048 a owl:Class .
#
# ns1:data_2535 a owl:Class .
#
# ns1:data_2968 a owl:Class .
#
# ns1:data_2984 a owl:Class ;
#     ns1:has_topic ns1:topic_0602 .
#
# ns1:data_3108 a owl:Class .
#
# ns1:data_3110 a owl:Class .
#
# ns1:data_3112 a owl:Class .
#
# ns1:data_3210 a owl:Class .
#
# ns1:topic_0108 a owl:Class .
#
# ns1:topic_0123 a owl:Class .
#
# ns1:topic_0154 a owl:Class .
#
# ns1:topic_2229 a owl:Class .
#
# ns1:topic_2259 a owl:Class .
#
# ns1:topic_2275 a owl:Class .
#
# ns1:topic_3168 a owl:Class .
#
# ns1:topic_3301 a owl:Class .
#
# ns1:topic_3489 a owl:Class .
#
# ns1:data_0582 a owl:Class ;
#     ns1:has_topic ns1:topic_0089 .
#
# ns1:data_0858 a owl:Class .
#
# ns1:data_0925 a owl:Class .
#
# ns1:data_0955 a owl:Class ;
#     ns1:has_topic ns1:topic_3489 .
#
# ns1:data_0957 a owl:Class .
#
# ns1:data_1235 a owl:Class ;
#     ns1:has_topic ns1:topic_0623 .
#
# ns1:data_1274 a owl:Class ;
#     ns1:has_topic ns1:topic_0102 .
#
# ns1:data_1354 a owl:Class ;
#     ns1:has_topic ns1:topic_0160 .
#
# ns1:data_1461 a owl:Class .
#
# ns1:data_1598 a owl:Class .
#
# ns1:data_1772 a owl:Class .
#
# ns1:data_2531 a owl:Class .
#
# ns1:data_2600 a owl:Class ;
#     ns1:has_topic ns1:topic_0602 .
#
# ns1:topic_0080 a owl:Class .
#
# ns1:topic_0089 a owl:Class .
#
# ns1:topic_0196 a owl:Class .
#
# ns1:topic_0199 a owl:Class .
#
# ns1:topic_0632 a owl:Class .
#
# ns1:topic_0659 a owl:Class .
#
# ns1:topic_0804 a owl:Class .
#
# ns1:topic_2814 a owl:Class .
#
# ns1:topic_3068 a owl:Class .
#
# ns1:data_0849 a owl:Class .
#
# ns1:data_0916 a owl:Class .
#
# ns1:data_1460 a owl:Class ;
#     ns1:has_topic ns1:topic_2814 .
#
# ns1:data_1597 a owl:Class ;
#     ns1:has_topic ns1:topic_0203 .
#
# ns1:data_2977 a owl:Class .
#
# ns1:data_3111 a owl:Class ;
#     ns1:has_topic ns1:topic_0203 .
#
# ns1:topic_0102 a owl:Class .
#
# ns1:topic_0130 a owl:Class .
#
# ns1:topic_0157 a owl:Class .
#
# ns1:data_0872 a owl:Class ;
#     ns1:has_topic ns1:topic_0084 .
#
# ns1:topic_0097 a owl:Class .
#
# ns1:topic_0602 a owl:Class .
#
# ns1:data_0883 a owl:Class ;
#     ns1:has_topic ns1:topic_0081 .
#
# ns1:data_0906 a owl:Class ;
#     ns1:has_topic ns1:topic_0128 .
#
# ns1:topic_0114 a owl:Class .
#
# ns1:topic_1775 a owl:Class .
#
# ns1:topic_0081 a owl:Class .
#
# ns1:data_0863 a owl:Class ;
#     ns1:has_topic ns1:topic_0080 .
#
# ns1:data_2044 a owl:Class ;
#     ns1:has_topic ns1:topic_0080 .
#
# ns1:topic_0084 a owl:Class .
#
# ns1:topic_0203 a owl:Class .
#
# ns1:topic_1317 a owl:Class .
#
# ns1:data_1255 a owl:Class .
#
# ns1:topic_0128 a owl:Class .
#
# ns1:data_0943 a owl:Class ;
#     ns1:has_topic ns1:topic_0121 .
#
# ns1:topic_0121 a owl:Class .
#
# ns1:topic_0160 a owl:Class .

# %%
test_r_6 = """
PREFIX edam: <http://edamontology.org/>
SELECT * WHERE {
    # ?concept rdf:type owl:Class .
    # ?concept edam:has_input ?data .
    # ?data edam:has_operation ?operation .
}
"""

res = edam_kg_2.query(test_r_6)
for row in res:
    print(f"{row.concept} has operation {row.operation} through input {row.data}")
